# %% [markdown]
# LOADING THE PARQUET FILE

# %%
import pandas as pd
path = "/Users/saptarshiroy/Desktop/PROJECTS/RAINFALL DETECTION/data/final_dataset.parquet"
df = pd.read_parquet(path)
df.head()
# Out:
#    grid_id  lat_center  lon_center       date  rain_mm  wind_speed  lst_k  \
# 0        1       6.125      68.125 2025-07-15      0.0    4.068408  200.0
# 1        2       6.125      68.375 2025-07-15      0.0    4.068408  200.0
# 2        3       6.125      68.625 2025-07-15      0.0    4.658631  200.0
# 3        4       6.125      68.875 2025-07-15      0.0    5.248854  200.0
# 4        5       6.125      69.125 2025-07-15      0.0    5.299462  200.0
#
#         cer       cot        uth         olr       hem  day  month  year  \
# 0  5.250136  5.609405  47.262684  254.961426  0.000000   15      7  2025
# 1  5.250136  5.609405  47.747299  255.317398  0.000000   15      7  2025
# 2  5.250136  5.609405  47.985130  255.322098  0.019742   15      7  2025
# 3  5.250136  5.609405  48.897644  254.586182  0.000000   15      7  2025
# 4  5.250136  5.609405  50.307243  254.094528  0.000000   15      7  2025
#
#    day_of_year  week_of_year  monsoon_flag
# ...

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30718 entries, 0 to 30717
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   grid_id       30718 non-null  int64
#  1   lat_center    30718 non-null  float64
#  2   lon_center    30718 non-null  float64
#  3   date          30718 non-null  datetime64[ns]
#  4   rain_mm       30718 non-null  float32
#  5   wind_speed    30718 non-null  float32
#  6   lst_k         30718 non-null  float64
#  7   cer           30718 non-null  float64
#  8   cot           30718 non-null  float64
#  9   uth           30718 non-null  float32
#  10  olr           30718 non-null  float32
#  11  hem           30718 non-null  float32
#  12  day           30718 non-null  int32
#  13  month         30718 non-null  int32
#  14  year          30718 non-null  int32
#  15  day_of_year   30718 non-null  int32
#  16  week_of_year  30718 non-null  int64
# ...

# %%
df.head()
df.tail()
# Out:
#        grid_id  lat_center  lon_center       date    rain_mm  wind_speed  \
# 30713    15355      37.875      96.625 2025-07-16   8.556721    7.026499
# 30714    15356      37.875      96.875 2025-07-16   7.091656    6.986221
# 30715    15357      37.875      97.125 2025-07-16   9.857591    6.966083
# 30716    15358      37.875      97.375 2025-07-16  11.435349    6.968682
# 30717    15359      37.875      97.625 2025-07-16  13.290012    6.805581
#
#        lst_k       cer       cot        uth         olr        hem  day  \
# 30713  200.0  3.140615  2.573338  69.727127  183.691437   5.290546   16
# 30714  200.0  2.854662  1.492897  64.659691  186.910324   5.910726   16
# 30715  200.0  2.662314  0.308044  72.191414  187.479523  12.010411   16
# 30716  200.0  2.564262  0.755270  65.180878  189.051727  21.325140   16
# 30717  200.0  2.540783  1.185559  55.500076  187.469467  27.555470   16
#
#        month  year  day_of_year  week_of_year  monsoon_flag
# ...

# %%
[col for col in df.columns if 'rain' in col.lower()]
# Out:
# ['rain_mm']

# %%
[col for col in df.columns if 'date' in col.lower() or 'time' in col.lower()]
# Out:
# ['date']

# %%
df.columns
# Out:
# Index(['grid_id', 'lat_center', 'lon_center', 'date', 'rain_mm', 'wind_speed',
#        'lst_k', 'cer', 'cot', 'uth', 'olr', 'hem', 'day', 'month', 'year',
#        'day_of_year', 'week_of_year', 'monsoon_flag'],
#       dtype='object')

# %%
[col for col in df.columns if 'date' in col.lower() or 'time' in col.lower()]
# Out:
# ['date']

# %%
df['date'].head()
# Out:
# 0   2025-07-15
# 1   2025-07-15
# 2   2025-07-15
# 3   2025-07-15
# 4   2025-07-15
# Name: date, dtype: datetime64[ns]

# %%
df['date'] = pd.to_datetime(df['date'])
